# %% [markdown]
# # Importing and loading the data.

# %%
# Importing the required libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading the data using "read_csv" method in pandas
data = pd.read_csv("water_potability.csv")

# %%
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# ## Starts here

# %% [markdown]
# ## Shortening the data (just optional)

# %%
# Selecting multiple rows and columns at a same time.
df = data.loc[0:20, ['ph', 'Hardness']]

# %%
df
# Out:
#            ph    Hardness
# 0         NaN  204.890455
# 1    3.716080  129.422921
# 2    8.099124  224.236259
# 3    8.316766  214.373394
# 4    9.092223  181.101509
# 5    5.584087  188.313324
# 6   10.223862  248.071735
# 7    8.635849  203.361523
# 8         NaN  118.988579
# 9   11.180284  227.231469
# 10   7.360640  165.520797
# 11   7.974522  218.693300
# 12   7.119824  156.704993
# 13        NaN  150.174923
# 14   7.496232  205.344982
# 15   6.347272  186.732881
# 16   7.051786  211.049406
# 17   9.181560  273.813807
# 18   8.975464  279.357167
# 19   7.371050  214.496610
# 20        NaN  227.435048

# %% [markdown]
# ## Starts here

# %%
df
# Out:
#            ph    Hardness
# 0         NaN  204.890455
# 1    3.716080  129.422921
# 2    8.099124  224.236259
# 3    8.316766  214.373394
# 4    9.092223  181.101509
# 5    5.584087  188.313324
# 6   10.223862  248.071735
# 7    8.635849  203.361523
# 8         NaN  118.988579
# 9   11.180284  227.231469
# 10   7.360640  165.520797
# 11   7.974522  218.693300
# 12   7.119824  156.704993
# 13        NaN  150.174923
# 14   7.496232  205.344982
# 15   6.347272  186.732881
# 16   7.051786  211.049406
# 17   9.181560  273.813807
# 18   8.975464  279.357167
# 19   7.371050  214.496610
# 20        NaN  227.435048

# %% [markdown]
# ## Starts here

# %% [markdown]
# ### Before we add any style.

# %%
plt.plot(df)

# %%
# use this command to get a list of the styles available in matplotlib.
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Now lets use one of the styles from the upper list 👆👆👆
# In my case, I will choose the "ggplot" style from the list.
plt.style.use("ggplot")

# %%
plt.plot(df)

# %%
# If we want to remove the style and get back to the default plot style then this is the command to do the same:
# plt.style.use('default')
